# %% [markdown]
# ### Imorting Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.naive_bayes import GaussianNB # Gaussian Naive Bayes
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ### Loading data

# %%
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(iris.target_names) # target labels
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ### Data Visualization

# %%
palette = sns.color_palette('Set2')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11,5))
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue=iris.target, data=iris_df, ax=ax1, palette=palette)
ax1.legend(labels=['setosa', 'versicolor', 'virginica'])
sns.scatterplot(x='petal length (cm)', y='petal width (cm)', hue=iris.target, data=iris_df, ax=ax2, palette=palette)
ax2.legend(labels=['setosa', 'versicolor', 'virginica'])
# Out:
# C:\Users\brahm\AppData\Local\Temp\ipykernel_17024\218075507.py:3: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue=iris.target, data=iris_df, ax=ax1, palette=palette)
# C:\Users\brahm\AppData\Local\Temp\ipykernel_17024\218075507.py:5: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.scatterplot(x='petal length (cm)', y='petal width (cm)', hue=iris.target, data=iris_df, ax=ax2, palette=palette)

# %% [markdown]
# ### Training and Testing split

# %%
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (120, 4)
# y_train: (120,)
# X_test: (30, 4)
# y_test: (30,)

# %% [markdown]
# ### Gaussian Naive Bayes instance

# %%
GNB_clf = GaussianNB()
GNB_clf
# Out:
# GaussianNB()

# %% [markdown]
# ### Training

# %%
GNB_clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = GNB_clf.predict(X_test)

# %% [markdown]
# ### Confusion Matrix

# %%
conf_m = confusion_matrix(y_pred, y_test)
sns.heatmap(conf_m, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Classification report

# %%
print('Classification report: \n', classification_report(y_pred, y_test))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.93      0.96        14
#            2       0.83      1.00      0.91         5
#
#     accuracy                           0.97        30
#    macro avg       0.94      0.98      0.96        30
# weighted avg       0.97      0.97      0.97        30
